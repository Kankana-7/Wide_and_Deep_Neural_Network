# %% [markdown]
# <a href="https://colab.research.google.com/github/Kankana-7/Wide_and_Deep_Neural_Network/blob/main/wide_and_deep_net_california_housing_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q wandb

# %%
import wandb
from google.colab import userdata

wandb.login(key=userdata.get('WANDB_API_KEY'))
# Out:
# wandb: Currently logged in as: kankana-ghosh (kankana-ghosh-xelpmoc-design-and-tech). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
import random
import numpy as np
import torch

def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
housing['data']
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
housing['data'].describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
housing['target']
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
type(housing['target'])
# Out:
# pandas.core.series.Series

# %%
housing['target'].describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: MedHouseVal, dtype: float64

# %%
housing['target'].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

X_train_full, X_test, y_train_full, y_test = train_test_split(housing['data'], housing['target'], test_size=0.25, random_state=42)
X_train_full.shape, X_test.shape, y_train_full.shape, y_test.shape
# Out:
# ((15480, 8), (5160, 8), (15480,), (5160,))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.25, random_state=42)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((11610, 8), (3870, 8), (11610,), (3870,))

# %%
X_means, X_stds = X_train.mean(axis=0), X_train.std(axis=0)
X_means.shape, X_stds.shape
# Out:
# ((8,), (8,))

# %%
X_means
# Out:
# MedInc           3.891759
# HouseAge        28.624548
# AveRooms         5.455937
# AveBedrms        1.099635
# Population    1424.281223
# AveOccup         2.958867
# Latitude        35.646432
# Longitude     -119.584363
# dtype: float64

# %%
X_stds
# Out:
# MedInc           1.909356
# HouseAge        12.641462
# AveRooms         2.550491
# AveBedrms        0.465480
# Population    1095.807192
# AveOccup         2.361482
# Latitude         2.134659
# Longitude        2.001019
# dtype: float64

# %%
X_train = (X_train - X_means) / X_stds
X_train.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  1.161000e+04  1.161000e+04  1.161000e+04  1.161000e+04  1.161000e+04
# mean   2.937644e-17  4.651270e-17  3.488453e-17 -8.047922e-17  1.836028e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.776442e+00 -2.185234e+00 -1.790655e+00 -1.646260e+00 -1.297018e+00
# 25%   -6.896351e-01 -8.404525e-01 -3.886801e-01 -1.992465e-01 -5.815633e-01
# 50%   -1.745922e-01  2.970006e-02 -8.272357e-02 -1.074281e-01 -2.347869e-01
# 75%    4.615387e-01  6.625383e-01  2.415810e-01  1.333583e-03  2.753393e-01
# max    5.817849e+00  1.849110e+00  5.350075e+01  5.271273e+01  1.357969e+01
#
#            AveOccup      Latitude     Longitude
# count  1.161000e+04  1.161000e+04  1.161000e+04
# mean   4.406467e-17 -1.878868e-15 -3.159192e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.598035e-01 -1.450551e+00 -2.381605e+00
# 25%   -2.250478e-01 -7.993932e-01 -1.112252e+00
# 50%   -6.004621e-02 -6.494863e-01  5.419052e-01
# 75%    1.369403e-01  9.713818e-01  7.867804e-01
# max    9.621650e+01  2.952963e+00  2.635838e+00

# %%
X_valid = (X_valid - X_means) / X_stds
X_valid.describe()
# Out:
#             MedInc     HouseAge     AveRooms    AveBedrms   Population  \
# count  3870.000000  3870.000000  3870.000000  3870.000000  3870.000000
# mean     -0.028165    -0.009035    -0.031897    -0.023662     0.011740
# std       0.988112     0.990529     0.778139     0.744590     1.162605
# min      -1.757535    -2.106129    -1.585831    -1.556747    -1.286067
# 25%      -0.706067    -0.840452    -0.402966    -0.201637    -0.572894
# 50%      -0.208033     0.029700    -0.100531    -0.108805    -0.232049
# 75%       0.442147     0.662538     0.223178     0.000785     0.278077
# max       5.817849     1.849110    18.581632    22.151490    31.262542
#
#           AveOccup     Latitude    Longitude
# count  3870.000000  3870.000000  3870.000000
# mean      0.250340     0.000540     0.001253
# std       9.975080     0.998800     1.002969
# min      -0.757803    -1.445867    -2.341625
# 25%      -0.216960    -0.804078    -1.106005
# 50%      -0.058949    -0.640117     0.521915
# 75%       0.133395     0.971382     0.786780
# max     525.252521     2.887379     2.555879

# %%
X_test = (X_test - X_means) / X_stds
X_test.describe()
# Out:
#             MedInc     HouseAge     AveRooms    AveBedrms   Population  \
# count  5160.000000  5160.000000  5160.000000  5160.000000  5160.000000
# mean     -0.023053     0.011503    -0.018323    -0.007686    -0.004441
# std       0.988748     0.989461     1.029445     1.216744     1.004324
# min      -1.776442    -2.185234    -1.807410    -1.288207    -1.292455
# 25%      -0.701943    -0.840452    -0.410190    -0.204446    -0.586126
# 50%      -0.199339     0.029700    -0.092927    -0.112967    -0.240262
# 75%       0.427653     0.662538     0.227899    -0.004724     0.265301
# max       5.817849     1.849110    49.824688    70.823708    13.412687
#
#           AveOccup     Latitude    Longitude
# count  5160.000000  5160.000000  5160.000000
# mean      0.001599    -0.027707     0.028362
# std       0.688820     1.003223     1.002691
# min      -0.717897    -1.455236    -2.331630
# 25%      -0.224560    -0.808762    -1.087265
# 50%      -0.058149    -0.668225     0.556898
# 75%       0.139083     0.962013     0.796775
# max      33.967041     2.910802     2.500907

# %%
from torch.utils.data import Dataset, DataLoader

class CaliforniaHousingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X.values, dtype=torch.float32)
        self.y = torch.tensor(y.values, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return {'input_wide': self.X[idx, :5], 'input_deep': self.X[idx, 2:], 'label': self.y[idx]}

# %%
train_set = CaliforniaHousingDataset(X_train, y_train)
len(train_set)
# Out:
# 11610

# %%
# Sanity check:
example = train_set[0]
example
# Out:
# {'input_wide': tensor([-0.1940, -1.0778, -0.9433,  0.0149,  0.0207]),
#  'input_deep': tensor([-0.9433,  0.0149,  0.0207, -0.5729,  0.9292, -1.4221]),
#  'label': tensor(1.4420)}

# %%
example['input_wide'].shape, example['input_deep'].shape, example['label'].shape
# Out:
# (torch.Size([5]), torch.Size([6]), torch.Size([]))

# %%
valid_set = CaliforniaHousingDataset(X_valid, y_valid)
test_set = CaliforniaHousingDataset(X_test, y_test)
len(valid_set), len(test_set)
# Out:
# (3870, 5160)

# %%
batch_size = 128
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2)
len(train_loader)
# Out:
# 91

# %%
# Sanity check:
batch = next(iter(train_loader))
batch['input_wide'].shape, batch['input_deep'].shape, batch['label'].shape
# Out:
# (torch.Size([128, 5]), torch.Size([128, 6]), torch.Size([128]))

# %%
batch['input_wide'].dtype, batch['input_deep'].dtype, batch['label'].dtype
# Out:
# (torch.float32, torch.float32, torch.float32)

# %%
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=2)
len(valid_loader), len(test_loader)
# Out:
# (31, 41)

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
import torch.nn as nn
from huggingface_hub import PyTorchModelHubMixin

class WideAndDeepNet(nn.Module, PyTorchModelHubMixin):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(6, 30)
        self.hidden2 = nn.Linear(30, 30)
        self.output = nn.Linear(35, 1)

    def forward(self, input_wide, input_deep, label=None):
        act = torch.relu(self.hidden1(input_deep))
        act = torch.relu(self.hidden2(act))
        concat = torch.cat([input_wide, act], axis=1)
        return self.output(concat)

# %%
model = WideAndDeepNet()
model.to(device)
# Out:
# WideAndDeepNet(
#   (hidden1): Linear(in_features=6, out_features=30, bias=True)
#   (hidden2): Linear(in_features=30, out_features=30, bias=True)
#   (output): Linear(in_features=35, out_features=1, bias=True)
# )

# %%
# Sanity check:
with torch.no_grad():
    preds = model(**batch)
preds.shape
# Out:
# torch.Size([128, 1])

# %%
loss_fn = nn.MSELoss(reduction='sum')
loss_fn
# Out:
# MSELoss()

# %%
# Sanity check:
with torch.no_grad():
    loss = loss_fn(preds.squeeze(), batch['label'])
loss
# Out:
# tensor(689.7277)

# %%
from torch.optim import Adam

learning_rate = 1e-3
optimizer = Adam(model.parameters(), lr=learning_rate)
n_epochs = 100
patience = 10

# %%
def train_epoch():
    model.train()
    train_loss = 0
    for batch in train_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        preds = model(**batch)
        loss = loss_fn(preds.squeeze(), batch['label'])
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    train_loss /= len(train_set)
    train_loss = round(train_loss, 4)
    return train_loss

# %%
def validate_epoch():
    model.eval()
    valid_loss = 0
    for batch in valid_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
            preds = model(**batch)
            loss = loss_fn(preds.squeeze(), batch['label'])
        valid_loss += loss.item()
    valid_loss /= len(valid_set)
    rmse = valid_loss**0.5
    valid_loss = round(valid_loss, 4)
    rmse = round(rmse, 4)
    return valid_loss, rmse

# %%
wandb_config = {
    'architecture': "WideAndDeepNet with Multiple Inputs",
    'dataset': "California Housing",
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'n_epochs': n_epochs,
    'patience': patience
}
wandb.init(
    project="wide-and-deep-net-california-housing",
    config=wandb_config,
    notes="Logging min of `train_loss`, `valid_loss` & `rmse`."
)
wandb.define_metric("train_loss", summary="min")
wandb.define_metric("valid_loss", summary="min")
wandb.define_metric("rmse", summary="min")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>/content/wandb/run-20250125_124445-lhkv6tl3</code>
# Syncing run <strong><a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/lhkv6tl3' target="_blank">rural-armadillo-4</a></strong> to <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing</a>
#  View run at <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/lhkv6tl3' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/lhkv6tl3</a>

# %%
no_progress_counter = 0
best_epoch = 0
best_rmse = float('inf')
for epoch in range(n_epochs):
    train_loss = train_epoch()

    valid_loss, rmse = validate_epoch()

    print(f"Epoch: {epoch}, Training Loss: {train_loss}, Validation Loss: {valid_loss}, RMSE: {rmse}")
    wandb.log({'train_loss': train_loss, 'valid_loss': valid_loss, 'rmse': rmse})

    if rmse < best_rmse:
        no_progress_counter = 0 # Reset.
        best_epoch = epoch
        best_rmse = rmse
        model.push_to_hub("wide-and-deep-net-california-housing-v2", commit_message=f"epoch: {epoch}, rmse: {rmse}")
    else:
        no_progress_counter += 1
    print("---")

    if no_progress_counter >= patience:
        print(f"No progress achieved for {no_progress_counter} epochs. Stopping early!")
        break
wandb.finish()
print("---")
print("Done!")
print(f"Best Epoch: {best_epoch}, Best RMSE: {best_rmse}")
# Out:
# Epoch: 0, Training Loss: 3.2612, Validation Loss: 7.9925, RMSE: 2.8271
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 1, Training Loss: 1.0131, Validation Loss: 3.0117, RMSE: 1.7354
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 2, Training Loss: 0.6691, Validation Loss: 2.1549, RMSE: 1.468
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 3, Training Loss: 0.5586, Validation Loss: 1.3959, RMSE: 1.1815
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 4, Training Loss: 0.5127, Validation Loss: 0.804, RMSE: 0.8967
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 5, Training Loss: 0.4877, Validation Loss: 0.7147, RMSE: 0.8454
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 6, Training Loss: 0.468, Validation Loss: 0.6971, RMSE: 0.8349
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 7, Training Loss: 0.453, Validation Loss: 0.5337, RMSE: 0.7306
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 8, Training Loss: 0.4375, Validation Loss: 0.5394, RMSE: 0.7344
# ---
# Epoch: 9, Training Loss: 0.4272, Validation Loss: 0.4504, RMSE: 0.6711
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 10, Training Loss: 0.4165, Validation Loss: 0.4692, RMSE: 0.685
# ---
# Epoch: 11, Training Loss: 0.4083, Validation Loss: 0.426, RMSE: 0.6527
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 12, Training Loss: 0.4018, Validation Loss: 0.4471, RMSE: 0.6686
# ---
# Epoch: 13, Training Loss: 0.3953, Validation Loss: 0.3976, RMSE: 0.6306
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 14, Training Loss: 0.3896, Validation Loss: 0.4706, RMSE: 0.686
# ---
# Epoch: 15, Training Loss: 0.386, Validation Loss: 0.3994, RMSE: 0.632
# ---
# Epoch: 16, Training Loss: 0.3807, Validation Loss: 0.4594, RMSE: 0.6778
# ---
# Epoch: 17, Training Loss: 0.3774, Validation Loss: 0.3506, RMSE: 0.5921
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 18, Training Loss: 0.3738, Validation Loss: 0.3673, RMSE: 0.6061
# ---
# Epoch: 19, Training Loss: 0.37, Validation Loss: 0.3757, RMSE: 0.613
# ---
# Epoch: 20, Training Loss: 0.3672, Validation Loss: 0.4223, RMSE: 0.6498
# ---
# Epoch: 21, Training Loss: 0.3665, Validation Loss: 0.3747, RMSE: 0.6122
# ---
# Epoch: 22, Training Loss: 0.3627, Validation Loss: 0.3698, RMSE: 0.6081
# ---
# Epoch: 23, Training Loss: 0.3573, Validation Loss: 0.3353, RMSE: 0.5791
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 24, Training Loss: 0.355, Validation Loss: 0.3334, RMSE: 0.5774
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 25, Training Loss: 0.3526, Validation Loss: 0.4691, RMSE: 0.6849
# ---
# Epoch: 26, Training Loss: 0.3502, Validation Loss: 0.3369, RMSE: 0.5804
# ---
# Epoch: 27, Training Loss: 0.3498, Validation Loss: 0.4084, RMSE: 0.6391
# ---
# Epoch: 28, Training Loss: 0.3475, Validation Loss: 0.3638, RMSE: 0.6032
# ---
# Epoch: 29, Training Loss: 0.3477, Validation Loss: 0.5691, RMSE: 0.7544
# ---
# Epoch: 30, Training Loss: 0.3436, Validation Loss: 0.3305, RMSE: 0.5749
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 31, Training Loss: 0.3422, Validation Loss: 0.4996, RMSE: 0.7068
# ---
# Epoch: 32, Training Loss: 0.3412, Validation Loss: 0.5779, RMSE: 0.7602
# ---
# Epoch: 33, Training Loss: 0.3426, Validation Loss: 1.4759, RMSE: 1.2149
# ---
# Epoch: 34, Training Loss: 0.3415, Validation Loss: 0.3155, RMSE: 0.5617
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 35, Training Loss: 0.3366, Validation Loss: 0.373, RMSE: 0.6107
# ---
# Epoch: 36, Training Loss: 0.3325, Validation Loss: 0.3168, RMSE: 0.5629
# ---
# Epoch: 37, Training Loss: 0.3343, Validation Loss: 0.4448, RMSE: 0.6669
# ---
# Epoch: 38, Training Loss: 0.3357, Validation Loss: 0.3342, RMSE: 0.5781
# ---
# Epoch: 39, Training Loss: 0.3316, Validation Loss: 0.3105, RMSE: 0.5573
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# ---
# Epoch: 40, Training Loss: 0.3283, Validation Loss: 0.5636, RMSE: 0.7507
# ---
# Epoch: 41, Training Loss: 0.3293, Validation Loss: 0.3137, RMSE: 0.5601
# ---
# Epoch: 42, Training Loss: 0.3285, Validation Loss: 0.6228, RMSE: 0.7892
# ---
# Epoch: 43, Training Loss: 0.3331, Validation Loss: 0.3256, RMSE: 0.5706
# ---
# Epoch: 44, Training Loss: 0.3235, Validation Loss: 0.3322, RMSE: 0.5764
# ---
# Epoch: 45, Training Loss: 0.3238, Validation Loss: 0.3951, RMSE: 0.6286
# ---
# Epoch: 46, Training Loss: 0.3243, Validation Loss: 0.8627, RMSE: 0.9288
# ---
# Epoch: 47, Training Loss: 0.3281, Validation Loss: 0.5594, RMSE: 0.7479
# ---
# Epoch: 48, Training Loss: 0.3231, Validation Loss: 1.0938, RMSE: 1.0458
# ---
# Epoch: 49, Training Loss: 0.3273, Validation Loss: 1.0028, RMSE: 1.0014
# ---
# No progress achieved for 10 epochs. Stopping early!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>rmse</td><td>█▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▃▁▁▁▁▁▂▁▁▁▁▂▂</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_loss</td><td>█▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-armadillo-4</strong> at: <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/lhkv6tl3' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/lhkv6tl3</a><br> View project at: <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250125_124445-lhkv6tl3/logs</code>
# ---
# Done!
# Best Epoch: 39, Best RMSE: 0.5573

# %%
model = WideAndDeepNet.from_pretrained("kankanaghosh/wide-and-deep-net-california-housing-v2")
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# WideAndDeepNet(
#   (hidden1): Linear(in_features=6, out_features=30, bias=True)
#   (hidden2): Linear(in_features=30, out_features=30, bias=True)
#   (output): Linear(in_features=35, out_features=1, bias=True)
# )

# %%
model.eval()
test_loss = 0
for batch in test_loader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        preds = model(**batch)
        loss = loss_fn(preds.squeeze(), batch['label'])
    test_loss += loss.item()
test_loss /= len(test_set)
rmse = test_loss**0.5
rmse = round(rmse, 4)
print(f"Test Set RMSE: {rmse}")
# Out:
# Test Set RMSE: 0.5756

# %%
new = test_set[:3]
new
# Out:
# {'input_wide': tensor([[-1.1578, -0.2867, -0.4955, -0.1662, -0.0295],
#          [-0.7125,  0.1088, -0.1633,  0.2016,  0.1284],
#          [-0.2156,  1.8491, -0.5798,  0.1853, -0.1043]]),
#  'input_deep': tensor([[-0.4955, -0.1662, -0.0295,  0.3890,  0.1937,  0.2870],
#          [-0.1633,  0.2016,  0.1284, -0.1182, -0.2372,  0.0621],
#          [-0.5798,  0.1853, -0.1043, -0.6769,  1.0089, -1.4271]]),
#  'label': tensor([0.4770, 0.4580, 5.0000])}

# %%
new = {k: v.to(device) for k, v in new.items() if k in ['input_wide', 'input_deep']}
new
# Out:
# {'input_wide': tensor([[-1.1578, -0.2867, -0.4955, -0.1662, -0.0295],
#          [-0.7125,  0.1088, -0.1633,  0.2016,  0.1284],
#          [-0.2156,  1.8491, -0.5798,  0.1853, -0.1043]]),
#  'input_deep': tensor([[-0.4955, -0.1662, -0.0295,  0.3890,  0.1937,  0.2870],
#          [-0.1633,  0.2016,  0.1284, -0.1182, -0.2372,  0.0621],
#          [-0.5798,  0.1853, -0.1043, -0.6769,  1.0089, -1.4271]])}

# %%
with torch.no_grad():
    preds = model(**new)
preds.squeeze()
# Out:
# tensor([0.5212, 1.2538, 3.6379])
