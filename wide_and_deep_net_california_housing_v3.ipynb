# %% [markdown]
# <a href="https://colab.research.google.com/github/Kankana-7/Wide_and_Deep_Neural_Network/blob/main/wide_and_deep_net_california_housing_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q wandb

# %%
import wandb
from google.colab import userdata

wandb.login(key=userdata.get('WANDB_API_KEY'))
# Out:
# wandb: Currently logged in as: kankana-ghosh (kankana-ghosh-xelpmoc-design-and-tech). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os
import random
import numpy as np
import torch

def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
housing['data']
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
housing['data'].describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
housing['target']
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
type(housing['target'])
# Out:
# pandas.core.series.Series

# %%
housing['target'].describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: MedHouseVal, dtype: float64

# %%
housing['target'].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

X_train_full, X_test, y_train_full, y_test = train_test_split(housing['data'], housing['target'], test_size=0.25, random_state=42)
X_train_full.shape, X_test.shape, y_train_full.shape, y_test.shape
# Out:
# ((15480, 8), (5160, 8), (15480,), (5160,))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.25, random_state=42)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((11610, 8), (3870, 8), (11610,), (3870,))

# %%
X_means, X_stds = X_train.mean(axis=0), X_train.std(axis=0)
X_means.shape, X_stds.shape
# Out:
# ((8,), (8,))

# %%
X_means
# Out:
# MedInc           3.891759
# HouseAge        28.624548
# AveRooms         5.455937
# AveBedrms        1.099635
# Population    1424.281223
# AveOccup         2.958867
# Latitude        35.646432
# Longitude     -119.584363
# dtype: float64

# %%
X_stds
# Out:
# MedInc           1.909356
# HouseAge        12.641462
# AveRooms         2.550491
# AveBedrms        0.465480
# Population    1095.807192
# AveOccup         2.361482
# Latitude         2.134659
# Longitude        2.001019
# dtype: float64

# %%
X_train = (X_train - X_means) / X_stds
X_train.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  1.161000e+04  1.161000e+04  1.161000e+04  1.161000e+04  1.161000e+04
# mean   2.937644e-17  4.651270e-17  3.488453e-17 -8.047922e-17  1.836028e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.776442e+00 -2.185234e+00 -1.790655e+00 -1.646260e+00 -1.297018e+00
# 25%   -6.896351e-01 -8.404525e-01 -3.886801e-01 -1.992465e-01 -5.815633e-01
# 50%   -1.745922e-01  2.970006e-02 -8.272357e-02 -1.074281e-01 -2.347869e-01
# 75%    4.615387e-01  6.625383e-01  2.415810e-01  1.333583e-03  2.753393e-01
# max    5.817849e+00  1.849110e+00  5.350075e+01  5.271273e+01  1.357969e+01
#
#            AveOccup      Latitude     Longitude
# count  1.161000e+04  1.161000e+04  1.161000e+04
# mean   4.406467e-17 -1.878868e-15 -3.159192e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.598035e-01 -1.450551e+00 -2.381605e+00
# 25%   -2.250478e-01 -7.993932e-01 -1.112252e+00
# 50%   -6.004621e-02 -6.494863e-01  5.419052e-01
# 75%    1.369403e-01  9.713818e-01  7.867804e-01
# max    9.621650e+01  2.952963e+00  2.635838e+00

# %%
X_valid = (X_valid - X_means) / X_stds
X_valid.describe()
# Out:
#             MedInc     HouseAge     AveRooms    AveBedrms   Population  \
# count  3870.000000  3870.000000  3870.000000  3870.000000  3870.000000
# mean     -0.028165    -0.009035    -0.031897    -0.023662     0.011740
# std       0.988112     0.990529     0.778139     0.744590     1.162605
# min      -1.757535    -2.106129    -1.585831    -1.556747    -1.286067
# 25%      -0.706067    -0.840452    -0.402966    -0.201637    -0.572894
# 50%      -0.208033     0.029700    -0.100531    -0.108805    -0.232049
# 75%       0.442147     0.662538     0.223178     0.000785     0.278077
# max       5.817849     1.849110    18.581632    22.151490    31.262542
#
#           AveOccup     Latitude    Longitude
# count  3870.000000  3870.000000  3870.000000
# mean      0.250340     0.000540     0.001253
# std       9.975080     0.998800     1.002969
# min      -0.757803    -1.445867    -2.341625
# 25%      -0.216960    -0.804078    -1.106005
# 50%      -0.058949    -0.640117     0.521915
# 75%       0.133395     0.971382     0.786780
# max     525.252521     2.887379     2.555879

# %%
X_test = (X_test - X_means) / X_stds
X_test.describe()
# Out:
#             MedInc     HouseAge     AveRooms    AveBedrms   Population  \
# count  5160.000000  5160.000000  5160.000000  5160.000000  5160.000000
# mean     -0.023053     0.011503    -0.018323    -0.007686    -0.004441
# std       0.988748     0.989461     1.029445     1.216744     1.004324
# min      -1.776442    -2.185234    -1.807410    -1.288207    -1.292455
# 25%      -0.701943    -0.840452    -0.410190    -0.204446    -0.586126
# 50%      -0.199339     0.029700    -0.092927    -0.112967    -0.240262
# 75%       0.427653     0.662538     0.227899    -0.004724     0.265301
# max       5.817849     1.849110    49.824688    70.823708    13.412687
#
#           AveOccup     Latitude    Longitude
# count  5160.000000  5160.000000  5160.000000
# mean      0.001599    -0.027707     0.028362
# std       0.688820     1.003223     1.002691
# min      -0.717897    -1.455236    -2.331630
# 25%      -0.224560    -0.808762    -1.087265
# 50%      -0.058149    -0.668225     0.556898
# 75%       0.139083     0.962013     0.796775
# max      33.967041     2.910802     2.500907

# %%
from torch.utils.data import Dataset, DataLoader

class CaliforniaHousingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X.values, dtype=torch.float32)
        self.y = torch.tensor(y.values, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return {'input_wide': self.X[idx, :5], 'input_deep': self.X[idx, 2:], 'label': self.y[idx]}

# %%
train_set = CaliforniaHousingDataset(X_train, y_train)
len(train_set)
# Out:
# 11610

# %%
# Sanity check:
example = train_set[0]
example
# Out:
# {'input_wide': tensor([-0.1940, -1.0778, -0.9433,  0.0149,  0.0207]),
#  'input_deep': tensor([-0.9433,  0.0149,  0.0207, -0.5729,  0.9292, -1.4221]),
#  'label': tensor(1.4420)}

# %%
example['input_wide'].shape, example['input_deep'].shape, example['label'].shape
# Out:
# (torch.Size([5]), torch.Size([6]), torch.Size([]))

# %%
valid_set = CaliforniaHousingDataset(X_valid, y_valid)
test_set = CaliforniaHousingDataset(X_test, y_test)
len(valid_set), len(test_set)
# Out:
# (3870, 5160)

# %%
batch_size = 128
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2)
len(train_loader)
# Out:
# 91

# %%
# Sanity check:
batch = next(iter(train_loader))
batch['input_wide'].shape, batch['input_deep'].shape, batch['label'].shape
# Out:
# (torch.Size([128, 5]), torch.Size([128, 6]), torch.Size([128]))

# %%
batch['input_wide'].dtype, batch['input_deep'].dtype, batch['label'].dtype
# Out:
# (torch.float32, torch.float32, torch.float32)

# %%
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=2)
len(valid_loader), len(test_loader)
# Out:
# (31, 41)

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class WideAndDeepNetOutput:
    main_output: torch.Tensor
    aux_output: torch.Tensor
    main_loss: Optional[torch.Tensor] = None
    aux_loss: Optional[torch.Tensor] = None
    loss: Optional[torch.Tensor] = None

# %%
# Test:
output = WideAndDeepNetOutput(
    main_output=torch.tensor([[1.], [2.]]),
    aux_output=torch.tensor([[3.], [4.]])
)
output
# Out:
# WideAndDeepNetOutput(main_output=tensor([[1.],
#         [2.]]), aux_output=tensor([[3.],
#         [4.]]), main_loss=None, aux_loss=None, loss=None)

# %%
import torch.nn as nn
from huggingface_hub import PyTorchModelHubMixin

class WideAndDeepNet(nn.Module, PyTorchModelHubMixin):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(6, 30)
        self.hidden2 = nn.Linear(30, 30)
        self.main_head = nn.Linear(35, 1)
        self.aux_head = nn.Linear(30, 1)
        self.main_loss_fn = nn.MSELoss(reduction='sum')
        self.aux_loss_fn = nn.MSELoss(reduction='sum')

    def forward(self, input_wide, input_deep, label=None):
        act = torch.relu(self.hidden1(input_deep))
        act = torch.relu(self.hidden2(act))
        concat = torch.cat([input_wide, act], dim=1)
        main_output = self.main_head(concat)
        aux_output = self.aux_head(act)
        if label is not None:
            main_loss = self.main_loss_fn(main_output.squeeze(), label)
            aux_loss = self.aux_loss_fn(aux_output.squeeze(), label)
            loss = 0.9 * main_loss + 0.1 * aux_loss
            return WideAndDeepNetOutput(main_output, aux_output, main_loss, aux_loss, loss)
        else:
            return WideAndDeepNetOutput(main_output, aux_output)

# %%
model = WideAndDeepNet()
model.to(device)
# Out:
# WideAndDeepNet(
#   (hidden1): Linear(in_features=6, out_features=30, bias=True)
#   (hidden2): Linear(in_features=30, out_features=30, bias=True)
#   (main_head): Linear(in_features=35, out_features=1, bias=True)
#   (aux_head): Linear(in_features=30, out_features=1, bias=True)
#   (main_loss_fn): MSELoss()
#   (aux_loss_fn): MSELoss()
# )

# %%
# Sanity check:
with torch.no_grad():
    output = model(**batch)
output
# Out:
# WideAndDeepNetOutput(main_output=tensor([[ 0.1852],
#         [ 0.1022],
#         [-0.2765],
#         [ 0.1174],
#         [-0.0673],
#         [ 0.0294],
#         [-0.0721],
#         [ 0.3031],
#         [ 0.0191],
#         [-0.0305],
#         [ 0.2713],
#         [-0.0918],
#         [ 0.5857],
#         [-0.0025],
#         [ 0.0851],
#         [ 0.0882],
#         [ 0.2225],
#         [ 0.0614],
#         [ 0.3941],
#         [ 0.0227],
#         [ 0.1273],
#         [ 0.0041],
#         [-0.0945],
#         [ 0.1194],
#         [ 0.0618],
#         [ 0.0449],
#         [ 0.0622],
#         [ 0.1373],
#         [ 0.0082],
#         [-0.0024],
#         [ 0.0073],
#         [-0.0243],
#         [ 0.0516],
#         [ 0.2846],
#         [ 0.0186],
#         [ 0.1714],
#         [ 0.0513],
#         [ 0.3184],
#         [-0.0849],
#         [-0.0179],
#         [-0.1918],
#         [ 0.0557],
#         [ 0.0945],
#         [-0.0345],
#         [ 0.1968],
#         [ 0.0658],
#         [-0.0112],
#         [ 0.0522],
#         [ 0.0117],
#         [ 0.0494],
#         [ 0.0096],
#         [ 0.0890],
#         [ 0.0712],
#         [-0.0619],
#         [-0.0689],
#         [ 0.3185],
#         [ 0.0321],
#         [-0.1508],
#         [-0.1234],
#         [-0.4416],
#         [-0.0083],
#         [ 0.0021],
#         [-0.1583],
#         [ 0.0504],
#         [ 0.0649],
#         [ 0.0203],
#         [-0.0114],
#         [-0.0111],
#         [-0.2286],
#         [ 0.0203],
#         [ 0.0733],
#         [ 0.1424],
#         [ 0.5256],
#         [ 0.2166],
#         [ 0.2508],
#         [-0.1834],
#         [ 0.1583],
#         [-0.2679],
#         [-0.0103],
#         [ 0.0115],
#         [ 0.0426],
#         [ 0.0922],
#         [-0.0304],
#         [-0.0381],
#         [-0.0125],
#         [-0.0763],
#         [ 0.1813],
#         [ 0.0467],
#         [ 0.2315],
#         [ 0.0179],
#         [ 0.0256],
#         [ 0.0113],
#         [ 0.1074],
#         [ 0.1204],
#         [ 0.0738],
#         [-0.0029],
#         [ 0.0042],
#         [ 0.0196],
#         [ 0.0022],
#         [ 0.0744],
#         [-0.0564],
#         [-0.0312],
#         [ 0.1839],
#         [-0.0061],
#         [ 0.0498],
#         [ 0.0159],
#         [ 0.1797],
#         [-0.3454],
#         [ 0.0213],
#         [ 0.2010],
#         [ 0.1155],
#         [ 0.2541],
#         [ 1.2006],
#         [ 0.0496],
#         [ 0.3975],
#         [ 0.1066],
#         [ 0.0398],
#         [-0.1304],
#         [ 0.0919],
#         [ 0.1120],
#         [-0.0087],
#         [-0.0745],
#         [-0.0165],
#         [-0.0417],
#         [-0.0708],
#         [-0.0153],
#         [ 0.1401],
#         [ 0.2418]]), aux_output=tensor([[ 0.1715],
#         [ 0.0925],
#         [ 0.0644],
#         [ 0.1019],
#         [ 0.2475],
#         [ 0.1377],
#         [ 0.0844],
#         [ 0.2672],
#         [ 0.0669],
#         [ 0.1532],
#         [ 0.1972],
#         [ 0.1003],
#         [-0.0024],
#         [ 0.1447],
#         [ 0.1740],
#         [ 0.2037],
#         [ 0.1077],
#         [ 0.1497],
#         [-0.0062],
#         [ 0.0799],
#         [ 0.0928],
#         [ 0.1039],
#         [ 0.0809],
#         [ 0.1000],
#         [ 0.1733],
#         [ 0.2836],
#         [ 0.0840],
#         [ 0.1053],
#         [ 0.2017],
#         [ 0.1892],
#         [ 0.1099],
#         [ 0.1706],
#         [ 0.0960],
#         [ 0.0424],
#         [ 0.0605],
#         [ 0.1911],
#         [ 0.1030],
#         [ 0.0510],
#         [ 0.0574],
#         [ 0.0674],
#         [ 0.0801],
#         [ 0.1574],
#         [ 0.1043],
#         [ 0.0983],
#         [ 0.1444],
#         [ 0.1512],
#         [ 0.0740],
#         [ 0.2788],
#         [ 0.0794],
#         [ 0.0484],
#         [ 0.1913],
#         [ 0.0627],
#         [ 0.0856],
#         [ 0.0924],
#         [ 0.0512],
#         [ 0.0990],
#         [ 0.0847],
#         [ 0.0689],
#         [ 0.1717],
#         [-0.0372],
#         [ 0.1381],
#         [ 0.1824],
#         [ 0.1018],
#         [ 0.0839],
#         [ 0.1135],
#         [ 0.1933],
#         [ 0.2660],
#         [ 0.0922],
#         [ 0.0869],
#         [ 0.1483],
#         [ 0.1101],
#         [ 0.1133],
#         [-0.0092],
#         [ 0.2475],
#         [ 0.1149],
#         [ 0.0921],
#         [ 0.0938],
#         [ 0.0505],
#         [ 0.1336],
#         [ 0.0973],
#         [ 0.0927],
#         [ 0.1916],
#         [ 0.1071],
#         [ 0.0860],
#         [ 0.1087],
#         [ 0.2025],
#         [ 0.2280],
#         [ 0.1063],
#         [ 0.1130],
#         [ 0.0619],
#         [ 0.1111],
#         [ 0.2046],
#         [ 0.0888],
#         [ 0.1403],
#         [ 0.1828],
#         [ 0.0968],
#         [ 0.0807],
#         [ 0.0948],
#         [ 0.0951],
#         [ 0.0686],
#         [ 0.0949],
#         [ 0.1131],
#         [ 0.1923],
#         [ 0.2308],
#         [ 0.2295],
#         [ 0.1459],
#         [ 0.0628],
#         [ 0.0761],
#         [ 0.1284],
#         [ 0.0922],
#         [ 0.1237],
#         [ 0.0572],
#         [-0.2780],
#         [ 0.1934],
#         [ 0.0715],
#         [ 0.1178],
#         [ 0.0844],
#         [ 0.0668],
#         [ 0.1073],
#         [ 0.0860],
#         [ 0.1230],
#         [ 0.1891],
#         [ 0.1229],
#         [ 0.1229],
#         [ 0.1424],
#         [ 0.0990],
#         [ 0.2300],
#         [ 0.0566]]), main_loss=tensor(689.7277), aux_loss=tensor(652.1627), loss=tensor(685.9712))

# %%
output.main_output.shape, output.aux_output.shape
# Out:
# (torch.Size([128, 1]), torch.Size([128, 1]))

# %%
from torch.optim import Adam

learning_rate = 1e-3
optimizer = Adam(model.parameters(), lr=learning_rate)
n_epochs = 100
patience = 10

# %%
def train_epoch():
    model.train()
    train_main_loss = 0
    train_aux_loss = 0
    train_loss = 0
    for batch in train_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        output = model(**batch)
        loss = output.loss
        train_main_loss += output.main_loss.item()
        train_aux_loss += output.aux_loss.item()
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    train_main_loss = round(train_main_loss / len(train_set), 4)
    train_aux_loss = round(train_aux_loss / len(train_set), 4)
    train_loss = round(train_loss / len(train_set), 4)
    return train_main_loss, train_aux_loss, train_loss

# %%
def validate_epoch():
    model.eval()
    valid_main_loss = 0
    valid_aux_loss = 0
    valid_loss = 0
    for batch in valid_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
            output = model(**batch)
        valid_main_loss += output.main_loss.item()
        valid_aux_loss += output.aux_loss.item()
        valid_loss += output.loss.item()
    valid_main_loss /= len(valid_set)
    rmse = round(valid_main_loss**0.5, 4)
    valid_main_loss = round(valid_main_loss, 4)
    valid_aux_loss = round(valid_aux_loss / len(valid_set), 4)
    valid_loss = round(valid_loss / len(valid_set), 4)
    return valid_main_loss, valid_aux_loss, valid_loss, rmse

# %%
wandb_config = {
    'architecture': "WideAndDeepNet with Auxiliary Output",
    'dataset': "California Housing",
    'batch_size': batch_size,
    'learning_rate': learning_rate,
    'n_epochs': n_epochs,
    'patience': patience
}
wandb.init(
    project="wide-and-deep-net-california-housing",
    config=wandb_config,
    notes="Summary metrics: min of train_loss, valid_loss & rmse."
)
wandb.define_metric("train_loss", summary="min")
wandb.define_metric("valid_loss", summary="min")
wandb.define_metric("rmse", summary="min")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>/content/wandb/run-20250125_131114-3p6rhpsf</code>
# Syncing run <strong><a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/3p6rhpsf' target="_blank">smooth-sun-5</a></strong> to <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing</a>
#  View run at <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/3p6rhpsf' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/3p6rhpsf</a>

# %%
no_progress_counter = 0
best_epoch = 0
best_rmse = float('inf')
for epoch in range(n_epochs):
    train_main_loss, train_aux_loss, train_loss = train_epoch()

    valid_main_loss, valid_aux_loss, valid_loss, rmse = validate_epoch()

    print(f"Epoch: {epoch}, Train Main Loss: {train_main_loss}, Train Aux Loss: {train_aux_loss}, Train Loss: {train_loss}")
    print(f"Valid Main Loss: {valid_main_loss}, Valid Aux Loss: {valid_aux_loss}, Valid Loss: {valid_loss}, RMSE: {rmse}")
    wandb.log({'train_loss': train_loss, 'valid_loss': valid_loss, 'rmse': rmse})

    if rmse < best_rmse:
        no_progress_counter = 0 # Reset.
        best_epoch = epoch
        best_rmse = rmse
        model.push_to_hub("wide-and-deep-net-california-housing-v3", commit_message=f"epoch: {epoch}, rmse: {rmse}")
    else:
        no_progress_counter += 1
    print("---")

    if no_progress_counter >= patience:
        print(f"No progress achieved for {no_progress_counter} epochs. Stopping early!")
        break
wandb.finish()
print("---")
print("Done!")
print(f"Best Epoch: {best_epoch}, Best RMSE: {best_rmse}")
# Out:
# Epoch: 0, Train Main Loss: 3.3295, Train Aux Loss: 3.7327, Train Loss: 3.3699
# Valid Main Loss: 9.6897, Valid Aux Loss: 3.3341, Valid Loss: 9.0541, RMSE: 3.1128
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 1, Train Main Loss: 1.048, Train Aux Loss: 1.3478, Train Loss: 1.0779
# Valid Main Loss: 4.8447, Valid Aux Loss: 2.5351, Valid Loss: 4.6137, RMSE: 2.2011
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 2, Train Main Loss: 0.696, Train Aux Loss: 0.9384, Train Loss: 0.7202
# Valid Main Loss: 2.996, Valid Aux Loss: 1.5437, Valid Loss: 2.8508, RMSE: 1.7309
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 3, Train Main Loss: 0.5692, Train Aux Loss: 0.76, Train Loss: 0.5883
# Valid Main Loss: 1.7818, Valid Aux Loss: 0.9051, Valid Loss: 1.6941, RMSE: 1.3348
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 4, Train Main Loss: 0.5222, Train Aux Loss: 0.6784, Train Loss: 0.5378
# Valid Main Loss: 1.4299, Valid Aux Loss: 0.7372, Valid Loss: 1.3606, RMSE: 1.1958
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 5, Train Main Loss: 0.4958, Train Aux Loss: 0.6428, Train Loss: 0.5105
# Valid Main Loss: 1.1868, Valid Aux Loss: 0.6371, Valid Loss: 1.1318, RMSE: 1.0894
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 6, Train Main Loss: 0.4761, Train Aux Loss: 0.6164, Train Loss: 0.4901
# Valid Main Loss: 0.9034, Valid Aux Loss: 0.5987, Valid Loss: 0.873, RMSE: 0.9505
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch: 7, Train Main Loss: 0.4612, Train Aux Loss: 0.6017, Train Loss: 0.4753
# Valid Main Loss: 0.7905, Valid Aux Loss: 0.5816, Valid Loss: 0.7696, RMSE: 0.8891
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# ---
# Epoch:
# Valid Main Loss: 0.3117, Valid Aux Loss: 0.3756, Valid Loss: 0.3181, RMSE: 0.5583
# ---
# Epoch: 50, Train Main Loss: 0.3225, Train Aux Loss: 0.3827, Train Loss: 0.3285
# Valid Main Loss: 0.4633, Valid Aux Loss: 0.7345, Valid Loss: 0.4904, RMSE: 0.6806
# ---
# Epoch: 51, Train Main Loss: 0.3238, Train Aux Loss: 0.3832, Train Loss: 0.3298
# Valid Main Loss: 0.3175, Valid Aux Loss: 0.3729, Valid Loss: 0.323, RMSE: 0.5634
# ---
# No progress achieved for 10 epochs. Stopping early!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>rmse</td><td>█▆▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">smooth-sun-5</strong> at: <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/3p6rhpsf' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing/runs/3p6rhpsf</a><br> View project at: <a href='https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing' target="_blank">https://wandb.ai/kankana-ghosh-xelpmoc-design-and-tech/wide-and-deep-net-california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250125_131114-3p6rhpsf/logs</code>
# ---
# Done!
# Best Epoch: 41, Best RMSE: 0.5562

# %%
model = WideAndDeepNet.from_pretrained("kankanaghosh/wide-and-deep-net-california-housing-v3")
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/5.41k [00:00<?, ?B/s]
# WideAndDeepNet(
#   (hidden1): Linear(in_features=6, out_features=30, bias=True)
#   (hidden2): Linear(in_features=30, out_features=30, bias=True)
#   (main_head): Linear(in_features=35, out_features=1, bias=True)
#   (aux_head): Linear(in_features=30, out_features=1, bias=True)
#   (main_loss_fn): MSELoss()
#   (aux_loss_fn): MSELoss()
# )

# %%
model.eval()
test_main_loss = 0
for batch in test_loader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        output = model(**batch)
    test_main_loss += output.main_loss.item()
test_main_loss /= len(test_set)
rmse = round(test_main_loss**0.5, 4)
print(f"Test Set RMSE: {rmse}")
# Out:
# Test Set RMSE: 0.5745

# %%
new = test_set[:3]
new
# Out:
# {'input_wide': tensor([[-1.1578, -0.2867, -0.4955, -0.1662, -0.0295],
#          [-0.7125,  0.1088, -0.1633,  0.2016,  0.1284],
#          [-0.2156,  1.8491, -0.5798,  0.1853, -0.1043]]),
#  'input_deep': tensor([[-0.4955, -0.1662, -0.0295,  0.3890,  0.1937,  0.2870],
#          [-0.1633,  0.2016,  0.1284, -0.1182, -0.2372,  0.0621],
#          [-0.5798,  0.1853, -0.1043, -0.6769,  1.0089, -1.4271]]),
#  'label': tensor([0.4770, 0.4580, 5.0000])}

# %%
new = {k: v.to(device) for k, v in new.items() if k in ['input_wide', 'input_deep']}
new
# Out:
# {'input_wide': tensor([[-1.1578, -0.2867, -0.4955, -0.1662, -0.0295],
#          [-0.7125,  0.1088, -0.1633,  0.2016,  0.1284],
#          [-0.2156,  1.8491, -0.5798,  0.1853, -0.1043]]),
#  'input_deep': tensor([[-0.4955, -0.1662, -0.0295,  0.3890,  0.1937,  0.2870],
#          [-0.1633,  0.2016,  0.1284, -0.1182, -0.2372,  0.0621],
#          [-0.5798,  0.1853, -0.1043, -0.6769,  1.0089, -1.4271]])}

# %%
with torch.no_grad():
    output = model(**new)
output
# Out:
# WideAndDeepNetOutput(main_output=tensor([[0.5198],
#         [1.2918],
#         [3.6600]]), aux_output=tensor([[0.8225],
#         [1.2639],
#         [3.4985]]), main_loss=None, aux_loss=None, loss=None)

# %%
output.main_output.squeeze()
# Out:
# tensor([0.5198, 1.2918, 3.6600])
